# %% [markdown]
# # This notebook includes anorthosite paleointensity result analyses using the Bias Corrected Estimation of Paleointensity (BiCEP) method

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
# %matplotlib inline
from IPython.display import Image

# %%
import sys
sys.path.append('../BiCEP_modules_and_scripts/') 
#The BiCEP_functions library imports all other needed libraries
import BiCEP_functions as BiCEP

# %% [markdown]
# ## Generate Arai plot table for AX PINT results

# %%
BiCEP.generate_arai_plot_table('AX_all')
# Out:
# -I- Using online data model
# -I- Getting method codes from earthref.org
# -I- Importing controlled vocabularies from https://earthref.org
# Working on: AX1-1a
# Working on: AX1-2a
# Working on: AX1-3a
# Working on: AX10-1a
# Working on: AX11-1a
# Working on: AX11-2a
# Working on: AX11-3a
# Working on: AX12-1a
# Working on: AX12-2a
# Working on: AX12-4a
# Working on: AX13-2a
# Working on: AX13-3a
# Working on: AX13-4a
# Working on: AX15-1a
# Working on: AX15-2a
# Working on: AX15-3a
# Working on: AX16-1a
# Working on: AX16-2a
# Working on: AX16-4a
# Working on: AX3-3a
# Working on: AX3-4a
# Working on: AX3-6a
# Working on: AX5-2a
# Working on: AX5-3a
# Working on: AX7-1a
# Working on: AX7-2a
# Working on: AX7-3a
# Working on: AX9-1a
# Working on: AX1-4a
# Working on: AX1-5a
# Working on: AX1-7a
# Working on: AX10-2a
# Working on: AX10-3a
# Working on: AX11-4a
# Working on: AX11-5a
# Working on: AX11-6a
# Working on: AX11-9a
# Working on: AX12-10a
# Working on: AX12-11a
# ...

# %%
data=BiCEP.ThellierData('AX_all.csv')
print(data)
# Out:
# Set of Thellier Data Containing the Sites:
# AX1	(6 specimens)
# AX10	(3 specimens)
# AX11	(7 specimens)
# AX12	(14 specimens)
# AX13	(7 specimens)
# AX15	(6 specimens)
# AX16	(15 specimens)
# AX3	(6 specimens)
# AX5	(2 specimens)
# AX7	(3 specimens)
# AX9	(1 specimens)
# AX22	(10 specimens)
# AX6	(3 specimens)
# AX8	(3 specimens)

# %% [markdown]
# # Data processing and analysis

# %% [markdown]
# ### Looking at site and specimen data

# %%
AX1=data['AX1']
AX3=data['AX3']
AX5=data['AX5']
AX6=data['AX6']
AX7=data['AX7']
AX8=data['AX8']
AX9=data['AX9']
AX10=data['AX10']
AX11=data['AX11']
AX12=data['AX12']
AX13=data['AX13']
AX15=data['AX15']
AX16=data['AX16']
AX22=data['AX22']

# %% [markdown]
# ## The BiCEP method- accounting for bias

# %% [markdown]
# ### AX1

# %%
AX1.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:7249 of 20000 iterations ended with a divergence (36.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX1.regplot(ax=ax[0])
ax[0].set_xlim(0.,1.6)
ax[0].set_ylim(0,20);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
ax[0].set_xlabel(r'$\vec{k}$');
#Plot our histogram
AX1_est, AX1_fit = AX1.histplot(ax=ax[1])
ax[1].set_xlim(0, 100)
fig.suptitle('AX1 estiamtes')
# plt.savefig('../code_output/AX1_BiCEP.pdf', bbox_inches='tight')
# plt.draw()
plt.show()
# plt.close()

# %% [markdown]
# ### AX3

# %%
AX3.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:3638 of 20000 iterations ended with a divergence (18.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX3.regplot(ax=ax[0])
ax[0].set_xlim(.6,1.8)
ax[0].set_ylim(0,50);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
ax[0].set_xlabel(r'$\vec{k}$');
#Plot our histogram
AX3_est, AX3_fit = AX3.histplot(ax=ax[1])
ax[1].set_xlim(0, 100)
fig.suptitle('AX3 estiamtes')
# plt.savefig('../code_output/AX3_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX5

# %%
AX5.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:885 of 20000 iterations ended with a divergence (4.42 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX5.regplot(ax[0])
ax[0].set_xlim(-1.,1.)
ax[0].set_ylim(20,60);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX5_est, AX5_fit = AX5.histplot(ax[1]);
ax[1].set_xlim(0, 100)
fig.suptitle('AX5 estiamtes')
# plt.savefig('../code_output/AX5_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX6

# %%
AX6.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:1756 of 20000 iterations ended with a divergence (8.78 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX6.regplot(ax[0])
ax[0].set_xlim(0.,1.2)
ax[0].set_ylim(0,100)
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX6_est, AX6_fit = AX6.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX6 estiamtes')
# plt.savefig('../code_output/AX6_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX7

# %%
AX7.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:3276 of 20000 iterations ended with a divergence (16.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX7.regplot(ax[0])
ax[0].set_xlim(.5,1.4)
ax[0].set_ylim(0,80);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX7_est, AX7_fit = AX7.histplot(ax[1]);
ax[1].set_xlim(0, 150)
fig.suptitle('AX7 estiamtes')
# plt.savefig('../code_output/AX7_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX8

# %%
AX8.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:4170 of 20000 iterations ended with a divergence (20.9 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX8.regplot(ax[0])
ax[0].set_xlim(-.3,1.)
ax[0].set_ylim(0,100);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')

#Plot our histogram
AX8_est, AX8_fit = AX8.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX8 estiamtes')
# plt.savefig('../code_output/AX8_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX9
#
# omitted because only one specimen was available

# %%
AX9
# Out:
# Site containing the specimens:
# AX9-1a

# %% [markdown]
# ### AX10

# %%
AX10.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:3300 of 20000 iterations ended with a divergence (16.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX10.regplot(ax[0])
ax[0].set_xlim(-.5,0.75)
ax[0].set_ylim(20,70);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX10_est, AX10_fit = AX10.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX10 estiamtes')
# plt.savefig('../code_output/AX10_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX11

# %%
AX11.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:2478 of 20000 iterations ended with a divergence (12.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX11.regplot(ax[0])
ax[0].set_xlim(-.5,.7)
ax[0].set_ylim(40,100);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX11_est, AX11_fit = AX11.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX11 estiamtes')
# plt.savefig('../code_output/AX11_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX12

# %%
AX12.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:1 of 20000 iterations ended with a divergence (0.005 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX12.regplot(ax[0])
ax[0].set_xlim(0,1.4)
ax[0].set_ylim(20,50);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX12_est, AX12_fit = AX12.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX12 estiamtes')
# plt.savefig('../code_output/AX12_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX13

# %%
AX13.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:2746 of 20000 iterations ended with a divergence (13.7 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX13.regplot(ax[0])
ax[0].set_xlim(-1.,.6)
ax[0].set_ylim(40,120);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX13_est, AX13_fit = AX13.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX13 estiamtes')
# plt.savefig('../code_output/AX13_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX15

# %%
AX15.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:1563 of 20000 iterations ended with a divergence (7.82 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:1 of 20000 iterations saturated the maximum tree depth of 10 (0.005 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX15.regplot(ax[0])
ax[0].set_xlim(0.,1.3)
ax[0].set_ylim(0,55);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX15_est, AX15_fit = AX15.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX15 estiamtes')
# plt.savefig('../code_output/AX15_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX16

# %%
AX16.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:5501 of 20000 iterations ended with a divergence (27.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX16.regplot(ax[0])
ax[0].set_xlim(0.,1.4)
ax[0].set_ylim(0,80)
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX16_est, AX16_fit = AX16.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX16 estiamtes')
# plt.savefig('../code_output/AX16_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### AX22

# %%
AX22.BiCEP_fit(model=BiCEP.model_circle_fast, n_samples=10000)
#This cell may generate warnings from the internal pystan code. 
#The main error to watch for is one about R_hat, which indicates the sampler hasn't converged, a "bad" run
# Out:
# WARNING:pystan:3 of 20000 iterations ended with a divergence (0.015 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.

# %%
#set up subplots
fig,ax=plt.subplots(1,2,figsize=(12,4))
#Plot our plot of the BiCEP fit.
AX22.regplot(ax[0])
ax[0].set_xlim(-1.,2.)
ax[0].set_ylim(0,30);
ax[0].set_ylabel('$B_{anc}$ ($\mu$T)')
#Plot our histogram
AX22_est, AX22_fit = AX22.histplot(ax[1]);
# ax[1].set_xlim(0, 100)
fig.suptitle('AX22 estiamtes')
# plt.savefig('../code_output/AX22_BiCEP.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## compare BiCEP probability estimate

# %%
cooling_rate = 0.74

AX_accepted_sites = ['AX6', 'AX8', 'AX10', 'AX12', 'AX16', 'AX11', 'AX13']
AX_rejected_sites = ['AX1', 'AX5', 'AX7']

AX_accepted_est_list = np.array([AX6_est, AX8_est, AX10_est, AX12_est, 
                    AX16_est, AX11_est, AX13_est])*cooling_rate
AX_rejected_est_list = np.array([AX1_est, AX5_est, AX7_est])*cooling_rate

AX_accepted_fit_list = np.array([AX6_fit, AX8_fit, AX10_fit, AX12_fit, 
                    AX16_fit, AX11_fit, AX13_fit])*cooling_rate
AX_rejected_fit_list = np.array([AX1_fit, AX5_fit, AX7_fit])*cooling_rate

AX_accepted_fit_frame = pd.DataFrame(AX_accepted_fit_list.T, columns = AX_accepted_sites)
AX_accepted_fit_frame.to_csv('../code_output/AX_accepted_fit_frame.csv')

AX_rejected_fit_frame = pd.DataFrame(AX_rejected_fit_list.T, columns = AX_rejected_sites)
AX_rejected_fit_frame.to_csv('../code_output/AX_rejected_fit_frame.csv')

# %%
fig, ax = plt.subplots(figsize=(12,6))

i=0
while i < len(AX_accepted_est_list):
    this_est = AX_accepted_est_list[i]
    this_pos = i 
    ax.text(this_pos + 0.1, this_est[1] + 10, AX_accepted_sites[i] )
    ax.fill_between([this_pos, this_pos+.5], this_est[0], this_est[2], color = 'red', alpha = 0.5)
    ax.plot([this_pos+.05, this_pos+.45], [this_est[1], this_est[1]], color = 'k')
    i = i + 1


j = 0

while j < len(AX_rejected_est_list):
    this_est = AX_rejected_est_list[j]
    this_pos = i + j 
    ax.text(this_pos+ 0.1, this_est[1] + 5, AX_rejected_sites[j] )
    ax.fill_between([this_pos, this_pos+.5], this_est[0], this_est[2], color = 'red', alpha = 0.1)
    ax.plot([this_pos+.05, this_pos+.45], [this_est[1], this_est[1]], color = 'grey')
    j = j + 1
    
plt.xlabel('anorthosite paleointensity sites', fontsize=12)
plt.xticks([], [])
plt.ylabel('absolute paleointensity estimate ($\mu$T)', fontsize=12)
plt.ylim(0, 200)
#     boxprops = dict(facecolor='lightcoral')
#     box = [
#     {
#         'label' : None
#         'whislo': None,    # Bottom whisker position
#         'q1'    : this_est[0],    # First quartile (25th percentile)
#         'med'   : this_est[1],    # Median         (50th percentile)
#         'q3'    : this_est[2],    # Third quartile (75th percentile)
#         'whishi': None,    # Top whisker position
#         'fliers': []        # Outliers
#     }]
#     ax.bxp(box, boxprops=boxprops, showfliers=False)
    
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,6))

AX_accepted_parts = ax.violinplot(AX_accepted_fit_list.T, positions=range(len(AX_accepted_fit_list)), showmedians=True,
        showextrema=False)


for pc in AX_accepted_parts['bodies']:
    pc.set_facecolor('red')
    pc.set_edgecolor('black')
    pc.set_alpha(0.5)
#     pc.set

AX_rejected_parts = ax.violinplot(AX_rejected_fit_list.T, 
                                  positions=range(len(AX_accepted_fit_list), len(AX_accepted_fit_list)+len(AX_rejected_fit_list)),showmedians=True,
                                  showextrema=False)


for pc in AX_rejected_parts['bodies']:
    pc.set_facecolor('red')
    pc.set_edgecolor('black')
    pc.set_alpha(0.2)
#     pc.set

plt.axvline(6.5, color = 'grey', alpha = 1, ls='--')
plt.text(2.5,170, 'accepted anorthosite sites', color = 'red', alpha = 1, fontsize=13)
plt.text(6.8,170, 'rejected \nanorthosite sites', color = 'red', alpha = 0.5, fontsize=13)


plt.ylim(0, 200)
plt.xticks(ticks = range(len(AX_accepted_fit_list)+len(AX_rejected_fit_list)), labels = AX_accepted_sites + AX_rejected_sites)
plt.ylabel('absolute paleointensity estimate ($\mu$T)', fontsize=12)
plt.xlabel('anorthosite paleointensity sites', fontsize=12)

# plt.savefig('../code_output/AX_BiCEP.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## anorthosite and diabase cooling unit pair
#
# <center>
#
# | Cooling unit #| AX sites| BD sites | Note |
# | :------------- | :----------: | -----------: | -----------: |
# | 1 | AX1 | BD1 | This xenolith site is hosted by BD1 diabase site and their directions agree very well|
# | 2 | AX3, AX4, AX5, AX6, AX7, AX8, AX9, AX10 | BD2 | All of these xenoliths are hosted by the same Carlton Peak BD2 sill |
# | 3 | AX11, AX13 | BD3 | These two anorthosite xenoliths are hosted by the same Kennedy Creek BD3 diabase sill |
# | 4 | AX12, AX14 | BD4 | These two anorthosite xenoliths are in close proximity hosted by BD4 diabase sill |
# | 5 | AX15, AX16, AX17, AX18 | BD5 | These anorthosite xenoliths are in close proximity hosted by a Silver Bay BD5 diabase sill |
# | 6 | AX19 | BD6 | This xenolith site is hosted by BD6 diabase site and their directions agree very well |
# | 7 | AX20 | BD7 | This xenolith site is hosted by BD7 diabase site and their directions agree very well |
# | 8 | AX22 | BD10| This xenolith site is hosted by BD10 diabase site and their directions agree very well |
# | 9 | AX21 | | This xenolith site is about 300 meters from BD7 diabase, and have a shallower direction than AX20 and BD7 |
# | 10 | | BD8 | single diabase site |
# | 11 | | BD9 | single diabase site |
# | 12 | | BD11 | single diabase site |
# | 13 | | BD12 | single diabase site |
# | 14 | | BD13 | single diabase site |
# | 15 | | BD15 | single diabase site |
# | 16 | | BD17 | single diabase site |
# |  | AX2 | | This xenolith is hosted by BD1 but it has an overprint with later secondary oxidation event |
# |  | | BD14 | Large overprint, not taken into calculation |
# |  | | BD16 | Large overprint, not taken into calculation |
# </center>
