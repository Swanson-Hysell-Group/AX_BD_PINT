# %% [markdown]
# # Notebook for displaying QDM maps of the Beaver River anorthosite vs. Duluth Complex Anorthositic Series anorthosite

# %%
import pmagpy.ipmag as ipmag
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import imageio
from PIL import Image
import matplotlib.cm as cm
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## MS99033 IRM parallel to the long axis of the thin section (parallel to the y axis in the QDM field of view)

# %%
MS99033_parallel_Bz = loadmat('../data/QDM/MS99033/Parallel_IRM/Bz_uc0.mat')
MS99033_parallel_Bz = MS99033_parallel_Bz['Bz'].reshape(300,374)

MS99033_paralleL_LED = Image.open('../data/QDM/MS99033/Parallel_IRM/LED.jpg').resize((374,300)).convert('LA')

# %%
xticks_list = np.array([0, 75, 150, 225, 300, 375])
yticks_list = np.array([0, 75, 150, 225])

# %%
vmin_QDM=-1e-5
vmax_QDM=1e-5

plt.figure(figsize = (37.4/3, 10))
# plt.imshow(MS99033_LED,alpha=0.6,cmap='Greys')
plt.imshow(np.flip(MS99033_parallel_Bz,0),cmap='seismic',vmin=vmin_QDM,vmax=vmax_QDM, alpha = .6)
cbar = plt.colorbar(fraction=0.05,shrink=0.85, format='%.e', ticks=np.linspace(vmin_QDM, vmax_QDM, 5))
cbar.ax.set_xlabel('Bz (T)', fontsize=16, labelpad=15)
cbar.ax.tick_params(labelsize=16)

cbar.update_ticks()
plt.xticks(ticks = xticks_list, labels = xticks_list* 4, fontsize=16)
plt.yticks(yticks_list,yticks_list* 4, fontsize=16)
# plt.savefig('../figure/MS99033_para_Bz_plot_with_scale.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ## MS99033 IRM orthogonal to the long axis of the thin section (parallel to the x axis in the QDM field of view)

# %%
MS99033_ortho_Bz = loadmat('../data/QDM/MS99033/Orthogonal_IRM/Bz_uc0.mat')
MS99033_ortho_Bz = MS99033_ortho_Bz['Bz'].reshape(300,374)

MS99033_ortho_LED = Image.open('../data/QDM/MS99033/Orthogonal_IRM/LED.jpg').resize((374,300)).convert('LA')

# %%
xticks_list = np.array([0, 50, 100, 150, 200, 250, 300, 350])
yticks_list = np.array([0, 50, 100, 150, 200, 250])

# %%
vmin_QDM=-5e-6
vmax_QDM=5e-6

plt.figure(figsize = (37.4/3, 10))
# plt.imshow(MS99033_LED,alpha=0.6,cmap='Greys')
plt.imshow(np.flip(MS99033_ortho_Bz,0),cmap='seismic',vmin=vmin_QDM,vmax=vmax_QDM, alpha = .6)
cbar = plt.colorbar(fraction=0.05,shrink=0.85, format='%.e', ticks=np.linspace(vmin_QDM, vmax_QDM, 5))
cbar.ax.set_xlabel('Bz (T)', fontsize=16, labelpad=15)
cbar.ax.tick_params(labelsize=16)

cbar.update_ticks()
plt.xticks(ticks = xticks_list, labels = xticks_list* 4, fontsize=16)
plt.yticks(yticks_list,yticks_list* 4, fontsize=16)
# plt.savefig('../figure/MS99033_ortho_Bz_plot_with_scale.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ## MS99033 IRM parallel to the long axis of the thin section (parallel to the y axis in the QDM field of view) after 300mT orthogonal IRM

# %%
MS99033_parallel_Bz_2 = loadmat('../data/QDM/MS99033/Parallel_IRM_2/Bz_uc0.mat')
MS99033_parallel_Bz_2 = MS99033_parallel_Bz_2['Bz'].reshape(300,374)

MS99033_paralleL_LED_2 = Image.open('../data/QDM/MS99033/Parallel_IRM_2/LED.jpg').resize((374,300)).convert('LA')

# %%
xticks_list = np.array([0, 50, 100, 150, 200, 250, 300, 350])
yticks_list = np.array([0, 50, 100, 150, 200, 250])

# %%
vmin_QDM=-2e-5
vmax_QDM=2e-5

plt.figure(figsize = (37.4/3, 10))
# plt.imshow(MS99033_LED,alpha=0.6,cmap='Greys')
plt.imshow(np.flip(MS99033_parallel_Bz_2,0),cmap='seismic',vmin=vmin_QDM,vmax=vmax_QDM, alpha = .6)
cbar = plt.colorbar(fraction=0.05,shrink=0.85, format='%.e', ticks=np.linspace(vmin_QDM, vmax_QDM, 5))
cbar.ax.set_xlabel('Bz (T)', fontsize=16, labelpad=15)
cbar.ax.tick_params(labelsize=16)

cbar.update_ticks()
plt.xticks(ticks = xticks_list, labels = xticks_list* 4, fontsize=16)
plt.yticks(yticks_list,yticks_list* 4, fontsize=16)
plt.savefig('../figure/MS99033_para_2_Bz_plot_with_scale.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ## Duluth Complex anorthosite 696 IRM parallel to thin section long axes

# %%
DC_696_para_IRM_Bz = loadmat('../data/QDM/DC_696/Parallel_IRM/Bz_uc0.mat')
DC_696_para_IRM_Bz = DC_696_para_IRM_Bz['Bz'].reshape(300,374)

DC_696_para_IRM_LED = Image.open('../data/QDM/DC_696/Parallel_IRM/LED.jpg').resize((374,300)).convert('LA')

# %%
vmin_QDM=-3e-4
vmax_QDM= 3e-4

plt.figure(figsize = (37.4/3, 10))
# plt.imshow(DC_696_para_IRM_LED,alpha=0.6,cmap='Greys')
plt.imshow(np.flip(DC_696_para_IRM_Bz,0),cmap='seismic',vmin=vmin_QDM,vmax=vmax_QDM, alpha = .6)
cbar = plt.colorbar(fraction=0.05,shrink=0.85, format='%.e', ticks=np.linspace(vmin_QDM, vmax_QDM, 5))
cbar.ax.set_xlabel('Bz (T)', fontsize=16, labelpad=15)
cbar.ax.tick_params(labelsize=16)

cbar.update_ticks()
plt.xticks(ticks = xticks_list, labels = xticks_list* 4, fontsize=16)
plt.yticks(yticks_list,yticks_list* 4, fontsize=16)
# plt.savefig('../figure/DC_696_para_Bz_plot_with_scale.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ## Duluth Complex anorthosite 696 IRM orthogonal to thin section long axes

# %%
DC_696_ortho_IRM_Bz = loadmat('../data/QDM/DC_696/Orthogonal_IRM/Bz_uc0.mat')
DC_696_ortho_IRM_Bz = DC_696_ortho_IRM_Bz['Bz'].reshape(300,374)

DC_696_ortho_IRM_LED = Image.open('../data/QDM/DC_696/Orthogonal_IRM/LED.jpg').resize((374,300)).convert('LA')

# %%
vmin_QDM=-3e-4
vmax_QDM= 3e-4

plt.figure(figsize = (37.4/3, 10))
# plt.imshow(DC_696_ortho_IRM_LED,alpha=0.6,cmap='Greys')
plt.imshow(np.flip(DC_696_ortho_IRM_Bz,0),cmap='seismic',vmin=vmin_QDM,vmax=vmax_QDM, alpha = .6)
cbar = plt.colorbar(fraction=0.05,shrink=0.85, format='%.e', ticks=np.linspace(vmin_QDM, vmax_QDM, 5))
cbar.ax.set_xlabel('Bz (T)', fontsize=16, labelpad=15)
cbar.ax.tick_params(labelsize=16)

cbar.update_ticks()
plt.xticks(ticks = xticks_list, labels = xticks_list* 4, fontsize=16)
plt.yticks(yticks_list,yticks_list* 4, fontsize=16)
plt.savefig('../figure/DC_696_ortho_Bz_plot_with_scale.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ## Duluth Complex anorthosite 696 IRM parallel to thin section long axes after 300mT orthogonal IRM

# %%
DC_696_para_IRM_Bz_2 = loadmat('../data/QDM/DC_696/Parallel_IRM_2/Bz_uc0.mat')
DC_696_para_IRM_Bz_2 = DC_696_para_IRM_Bz_2['Bz'].reshape(300,374)

DC_696_para_IRM_LED_2 = Image.open('../data/QDM/DC_696/Parallel_IRM_2/LED.jpg').resize((374,300)).convert('LA')

# %%
vmin_QDM=-3e-4
vmax_QDM= 3e-4

plt.figure(figsize = (37.4/3, 10))
# plt.imshow(DC_696_para_IRM_LED,alpha=0.6,cmap='Greys')
plt.imshow(np.flip(DC_696_para_IRM_Bz_2,0),cmap='seismic',vmin=vmin_QDM,vmax=vmax_QDM, alpha = .6)
cbar = plt.colorbar(fraction=0.05,shrink=0.85, format='%.e', ticks=np.linspace(vmin_QDM, vmax_QDM, 5))
cbar.ax.set_xlabel('Bz (T)', fontsize=16, labelpad=15)
cbar.ax.tick_params(labelsize=16)

cbar.update_ticks()
plt.xticks(ticks = xticks_list, labels = xticks_list* 4, fontsize=16)
plt.yticks(yticks_list,yticks_list* 4, fontsize=16)
plt.savefig('../figure/DC_696_para_2_Bz_plot_with_scale.png', bbox_inches='tight', dpi=300)
plt.show()
